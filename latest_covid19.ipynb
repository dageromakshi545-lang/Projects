# %% [markdown]
# # COVID-19 Data Analysis using pandas and numpy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cd=pd.read_csv("dataset/Latest Covid-19 India Status.csv")

# %% [markdown]
# # Q1. Print First And Last 10 Values From The Dataframe?

# %%
cd.head(10)
# Out:
#                                   State/UTs  Total Cases  Active  Discharged  \
# 0                       Andaman and Nicobar        10766       0       10637
# 1                            Andhra Pradesh      2340676       0     2325943
# 2                         Arunachal Pradesh        67049       0       66753
# 3                                     Assam       746159       5      738119
# 4                                     Bihar       855267       1      842952
# 5                                Chandigarh       100693       0       99508
# 6                              Chhattisgarh      1187695       0     1173505
# 7  Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                     Delhi      2040910      14     2014230
# 9                                       Goa       263346       3      259329
#
#    Deaths  Active Ratio  Discharge Ratio  Death Ratio  Population
# ...

# %%
cd.tail(10)
# Out:
#         State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 26     Puducherry       177547       0      175566    1981          0.00
# 27         Punjab       793644    1233      773073   19338          0.16
# 28      Rajasthan      1326465       2     1316727    9736          0.00
# 29         Sikkim        44927       4       44422     501          0.01
# 30     Tamil Nadu      3610655       5     3572569   38081          0.00
# 31      Telengana       844432       8      840313    4111          0.00
# 32        Tripura       108493       1      107550     942          0.00
# 33  Uttar Pradesh      2145431      57     2121662   23712          0.00
# 34    Uttarakhand       452571       0      444803    7768          0.00
# 35    West Bengal      2126282     135     2104592   21555          0.01
#
#     Discharge Ratio  Death Ratio  Population
# 26            98.88         1.12     2073074
# 27            97.41         2.44    34698876
# ...

# %% [markdown]
# # Q2.  How many Rows & Columns in Dataframe?

# %%
print("total number of rows",cd.shape[0])
print("total number of columns",cd.shape[1])
# Out:
# total number of rows 36
# total number of columns 9

# %% [markdown]
# # Q3. Display Data Types Of Each Column?

# %%
cd.dtypes
# Out:
# State/UTs           object
# Total Cases          int64
# Active               int64
# Discharged           int64
# Deaths               int64
# Active Ratio       float64
# Discharge Ratio    float64
# Death Ratio        float64
# Population           int64
# dtype: object

# %% [markdown]
# # Q4. Find Out The State Which Has Minimum Total Cases?

# %%
cd.loc[cd["Total Cases"].idxmin()]
# Out:
# State/UTs          Andaman and Nicobar
# Total Cases                      10766
# Active                               0
# Discharged                       10637
# Deaths                             129
# Active Ratio                       0.0
# Discharge Ratio                   98.8
# Death Ratio                        1.2
# Population                   100896618
# Name: 0, dtype: object

# %% [markdown]
# # Q5.Find Out The State Which Has Maximum Total Cases?

# %%
cd.loc[cd["Total Cases"].idxmax()]
# Out:
# State/UTs          Maharashtra
# Total Cases            8171048
# Active                     214
# Discharged             8022276
# Deaths                  148558
# Active Ratio               0.0
# Discharge Ratio          98.18
# Death Ratio               1.82
# Population              399001
# Name: 20, dtype: object

# %% [markdown]
# # Q6. Display All States Of India From DataFrame?

# %%
cd['State/UTs'] #.unique()
# Out:
# 0                          Andaman and Nicobar
# 1                               Andhra Pradesh
# 2                            Arunachal Pradesh
# 3                                        Assam
# 4                                        Bihar
# 5                                   Chandigarh
# 6                                 Chhattisgarh
# 7     Dadra and Nagar Haveli and Daman and Diu
# 8                                        Delhi
# 9                                          Goa
# 10                                     Gujarat
# 11                                     Haryana
# 12                            Himachal Pradesh
# 13                           Jammu and Kashmir
# 14                                   Jharkhand
# 15                                   Karnataka
# 16                                      Kerala
# 17                                      Ladakh
# 18                                 Lakshadweep
# 19                              Madhya Pradesh
# ...

# %% [markdown]
# # Q7. Display All The Data Of States Having Deaths Greater Than 10000?

# %%
cd[cd['Deaths']>10000]
# Out:
#          State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 1   Andhra Pradesh      2340676       0     2325943   14733          0.00
# 4            Bihar       855267       1      842952   12314          0.00
# 6     Chhattisgarh      1187695       0     1173505   14190          0.00
# 8            Delhi      2040910      14     2014230   26666          0.00
# 10         Gujarat      1291383       5     1280299   11079          0.00
# 11         Haryana      1078903      27     1068121   10755          0.00
# 15       Karnataka      4088769      12     4048399   40358          0.00
# 16          Kerala      6907241      18     6835181   72042          0.00
# 19  Madhya Pradesh      1056351       0     1045565   10786          0.00
# 20     Maharashtra      8171048     214     8022276  148558          0.00
# 27          Punjab       793644    1233      773073   19338          0.16
# 30      Tamil Nadu      3610655       5     3572569   38081          0.00
# ...

# %% [markdown]
# # Q8.Count The Total Cases Of India?

# %%
print(cd['Total Cases'].sum())
# Out:
# 44999085

# %% [markdown]
# # Q9.  What is the Death Ratio Of Maharashtra?

# %%
print(cd[cd['State/UTs']=='Maharashtra']['Deaths']/ cd[cd['State/UTs']=='Maharashtra']['Total Cases'])
# Out:
# 20    0.018181
# dtype: float64

# %% [markdown]
# # Q10. Which State Has Minimum Death Ratio?

# %%
cd.loc[cd["Death Ratio"].idxmin()]
# Out:
# State/UTs          Dadra and Nagar Haveli and Daman and Diu
# Total Cases                                           11592
# Active                                                    0
# Discharged                                            11588
# Deaths                                                    4
# Active Ratio                                            0.0
# Discharge Ratio                                       99.97
# Death Ratio                                            0.03
# Population                                        231502578
# Name: 7, dtype: object

# %% [markdown]
# # Q11. Find Out The Discharged Patients From The States Maharashtra,Karnataka,MP,Gujrat?

# %%
cd[cd['State/UTs'].isin(['Maharashtra','Karnataka','Madhya Pradesh','Gujarat'])]['Discharged']
# Out:
# 10    1280299
# 15    4048399
# 19    1045565
# 20    8022276
# Name: Discharged, dtype: int64

# %% [markdown]
# # Q12.  Find Out The States Having Total Cases between 1 lac to 5 lac?

# %%
cd[(cd['Total Cases']>=100000) & (cd['Total Cases']<=500000)]
# Out:
#             State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 5          Chandigarh       100693       0       99508    1185           0.0
# 9                 Goa       263346       3      259329    4014           0.0
# 12   Himachal Pradesh       322905       4      318660    4241           0.0
# 13  Jammu and Kashmir       482023       0      477231    4792           0.0
# 14          Jharkhand       443826       1      438491    5334           0.0
# 21            Manipur       140034       0      137885    2149           0.0
# 23            Mizoram       239560       1      238825     734           0.0
# 26         Puducherry       177547       0      175566    1981           0.0
# 32            Tripura       108493       1      107550     942           0.0
# 34        Uttarakhand       452571       0      444803    7768           0.0
#
#     Discharge Ratio  Death Ratio  Population
# 5             98.82         1.18    30501026
# ...

# %%
cd[cd["Total Cases"].between(100000,500000)]
# Out:
#             State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 5          Chandigarh       100693       0       99508    1185           0.0
# 9                 Goa       263346       3      259329    4014           0.0
# 12   Himachal Pradesh       322905       4      318660    4241           0.0
# 13  Jammu and Kashmir       482023       0      477231    4792           0.0
# 14          Jharkhand       443826       1      438491    5334           0.0
# 21            Manipur       140034       0      137885    2149           0.0
# 23            Mizoram       239560       1      238825     734           0.0
# 26         Puducherry       177547       0      175566    1981           0.0
# 32            Tripura       108493       1      107550     942           0.0
# 34        Uttarakhand       452571       0      444803    7768           0.0
#
#     Discharge Ratio  Death Ratio  Population
# 5             98.82         1.18    30501026
# ...

# %% [markdown]
# # Q13. Display All The Data Of The States Which Has Active Cases Less Than 1000?

# %%
cd[cd['Active'] < 1000]
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %% [markdown]
# # Q14. Make A Separate CSV File Of Data Of The States Which Has Active Cases Less Than 1000?

# %%
cd[cd['Active'] < 1000].to_csv("dataset/low_active_states.csv",index=False)

# %% [markdown]
# # Q15.  Total Number Of Deaths In India?

# %%
cd['Deaths'].sum()
# Out:
# np.int64(532027)

# %% [markdown]
# # Q16. Top 10 highest Population States in India?

# %%
cd.loc[cd.sort_values(by='Population',ascending=False).index.tolist(),["State/UTs","Population"]].head(10)
# Out:
#                                    State/UTs  Population
# 7   Dadra and Nagar Haveli and Daman and Diu   231502578
# 1                             Andhra Pradesh   128500364
# 14                                 Jharkhand   124904071
# 0                        Andaman and Nicobar   100896618
# 16                                    Kerala    91702478
# 34                               Uttarakhand    85002417
# 29                                    Sikkim    83697770
# 22                                 Meghalaya    79502477
# 10                                   Gujarat    70400153
# 31                                 Telengana    69599762
